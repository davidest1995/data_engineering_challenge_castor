# %% [markdown]
# # EDA inicial de los datasets
# Exploración básica de los datos en la capa Raw.

# %%
# Carga de transacciones
df_transacciones = spark.read.csv('file:/Workspace/Repos/your_email/castor-data-engineer/data/raw/transacciones_raw.csv', header=True, inferSchema=True)
display(df_transacciones)

# %%
# Carga de usuarios
df_usuarios = spark.read.json('file:/Workspace/Repos/your_email/castor-data-engineer/data/raw/usuarios_raw.json')
display(df_usuarios)
