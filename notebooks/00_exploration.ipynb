# %% [markdown]
# # EDA inicial de los datasets
# Exploración básica de los datos en la capa Raw.

# %%
# Carga de transacciones
df_transacciones = spark.read.csv('file:/Workspace/Users/davidest1995@gmail.com/data_engineering_challenge_castor/data/raw/transacciones_raw.csv', header=True, inferSchema=True)
display(df_transacciones)

# %%
# Carga de usuarios
df_usuarios = spark.read.option('multiLine', True).json('file:/Workspace/Users/davidest1995@gmail.com/data_engineering_challenge_castor/data/raw/usuarios_raw.json')
display(df_usuarios)
